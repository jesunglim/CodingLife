# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from matplotlib import font_manager, rc

# %%
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
csv = pd.read_csv("./DP_LIVE_20042022150640523.csv")

# %%
csv
# Out:
#       LOCATION INDICATOR SUBJECT MEASURE FREQUENCY  TIME     Value  Flag Codes
# 0          AUS       CPI     TOT  AGRWTH         A  2017  1.948647         NaN
# 1          AUS       CPI     TOT  AGRWTH         A  2018  1.911401         NaN
# 2          AUS       CPI     TOT  AGRWTH         A  2019  1.610768         NaN
# 3          AUS       CPI     TOT  AGRWTH         A  2020  0.846905         NaN
# 4          AUS       CPI     TOT  AGRWTH         A  2021  2.863910         NaN
# ..         ...       ...     ...     ...       ...   ...       ...         ...
# 249  EU27_2020       CPI     TOT  AGRWTH         A  2017  1.600000         NaN
# 250  EU27_2020       CPI     TOT  AGRWTH         A  2018  1.800000         NaN
# 251  EU27_2020       CPI     TOT  AGRWTH         A  2019  1.400000         NaN
# 252  EU27_2020       CPI     TOT  AGRWTH         A  2020  0.700000         NaN
# 253  EU27_2020       CPI     TOT  AGRWTH         A  2021  2.900000         NaN
#
# [254 rows x 8 columns]

# %%
csv = csv.drop(['INDICATOR'], axis=1)
csv = csv.drop(['SUBJECT'], axis=1)
csv = csv.drop(['MEASURE'], axis=1)
csv = csv.drop(['FREQUENCY'], axis=1)
csv = csv.drop(['Flag Codes'], axis=1)

# %%
csv
# Out:
#       LOCATION  TIME     Value
# 0          AUS  2017  1.948647
# 1          AUS  2018  1.911401
# 2          AUS  2019  1.610768
# 3          AUS  2020  0.846905
# 4          AUS  2021  2.863910
# ..         ...   ...       ...
# 249  EU27_2020  2017  1.600000
# 250  EU27_2020  2018  1.800000
# 251  EU27_2020  2019  1.400000
# 252  EU27_2020  2020  0.700000
# 253  EU27_2020  2021  2.900000
#
# [254 rows x 3 columns]

# %%
csv['LOCATION'].unique()
# Out:
# array(['AUS', 'AUT', 'BEL', 'CAN', 'CZE', 'DNK', 'FIN', 'FRA', 'DEU',
#        'GRC', 'HUN', 'ISL', 'IRL', 'ITA', 'JPN', 'KOR', 'LUX', 'MEX',
#        'NLD', 'NZL', 'NOR', 'POL', 'PRT', 'SVK', 'ESP', 'SWE', 'CHE',
#        'TUR', 'GBR', 'USA', 'BRA', 'CHL', 'CHN', 'EST', 'IND', 'IDN',
#        'ISR', 'RUS', 'SVN', 'ZAF', 'OECD', 'G-7', 'OECDE', 'COL', 'LVA',
#        'SAU', 'EA19', 'ARG', 'LTU', 'G-20', 'EU27_2020'], dtype=object)

# %%
contry_lst = []
contry_lst = csv['LOCATION'].unique()

# %%
df = pd.DataFrame({'TIME':[2017, 2018, 2019, 2020, 2021]})

# %%
df
# Out:
#    TIME
# 0  2017
# 1  2018
# 2  2019
# 3  2020
# 4  2021

# %%
for contry in contry_lst:
    df[contry]=np.NaN

# %%
df
# Out:
#    TIME  AUS  AUT  BEL  CAN  CZE  DNK  FIN  FRA  DEU  ...  G-7  OECDE  COL  \
# 0  2017  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN    NaN  NaN
# 1  2018  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN    NaN  NaN
# 2  2019  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN    NaN  NaN
# 3  2020  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN    NaN  NaN
# 4  2021  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN    NaN  NaN
#
#    LVA  SAU  EA19  ARG  LTU  G-20  EU27_2020
# 0  NaN  NaN   NaN  NaN  NaN   NaN        NaN
# 1  NaN  NaN   NaN  NaN  NaN   NaN        NaN
# 2  NaN  NaN   NaN  NaN  NaN   NaN        NaN
# 3  NaN  NaN   NaN  NaN  NaN   NaN        NaN
# 4  NaN  NaN   NaN  NaN  NaN   NaN        NaN
#
# [5 rows x 52 columns]

# %%
csv['LOCATION'].value_counts()
# Out:
# AUS          5
# RUS          5
# TUR          5
# GBR          5
# USA          5
# BRA          5
# CHL          5
# CHN          5
# EST          5
# IND          5
# IDN          5
# ISR          5
# SVN          5
# AUT          5
# ZAF          5
# OECD         5
# G-7          5
# OECDE        5
# COL          5
# LVA          5
# SAU          5
# EA19         5
# LTU          5
# G-20         5
# CHE          5
# SWE          5
# ESP          5
# SVK          5
# BEL          5
# CAN          5
# CZE          5
# DNK          5
# FIN          5
# FRA          5
# DEU          5
# GRC          5
# HUN          5
# ISL          5
# IRL          5
# ITA          5
# JPN          5
# KOR          5
# LUX          5
# MEX          5
# NLD          5
# NZL          5
# NOR          5
# POL          5
# PRT          5
# EU27_2020    5
# ARG          4
# Name: LOCATION, dtype: int64

# %%
csv.loc[0]
# Out:
# LOCATION         AUS
# TIME            2017
# Value       1.948647
# Name: 0, dtype: object

# %%
csv.loc[0]['LOCATION']
# Out:
# 'AUS'

# %%
csv['TIME'][21]
# Out:
# 2018

# %%
len(csv)
# Out:
# 254

# %%
cnt = 0

for i in range(len(csv)):
    for contry in contry_lst:
        if csv.loc[i]['LOCATION'] == contry:
            df[contry][cnt] = csv.loc[i]['Value']
            cnt += 1
    if cnt >= 5:
        cnt = 0
# Out:
# c:\python\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df
# Out:
#    TIME       AUS       AUT       BEL       CAN       CZE       DNK       FIN  \
# 0  2017  1.948647  2.081269  2.125971  1.596884  2.450534  1.147132  0.754015
# 1  2018  1.911401  1.998382  2.053165  2.268226  2.149495  0.813609  1.083821
# 2  2019  1.610768  1.530896  1.436820  1.949269  2.847876  0.758132  1.024094
# 3  2020  0.846905  1.381909  0.740792  0.717000  3.161295  0.420712  0.290555
# 4  2021  2.863910  2.766667  2.440248  3.395193  3.839845  1.853045  2.194574
#
#         FRA       DEU  ...       G-7     OECDE       COL       LVA       SAU  \
# 0  1.032283  1.509497  ...  1.769906  2.482395  4.312141  2.930369 -0.838195
# 1  1.850815  1.732168  ...  2.088463  3.020584  3.240234  2.534460  2.458142
# 2  1.108255  1.445667  ...  1.521069  2.612754  3.525493  2.811403 -2.093333
# 3  0.476499  0.506690  ...  0.874190  1.657686  2.524621  0.219061  3.445458
# 4  1.642331  3.142970  ...  3.493357  4.117882  3.495146  3.275814  3.063290
#
# ...

# %%
y_df = df.drop(['TIME'], axis=1)

# %%
y_df
# Out:
#         AUS       AUT       BEL       CAN       CZE       DNK       FIN  \
# 0  1.948647  2.081269  2.125971  1.596884  2.450534  1.147132  0.754015
# 1  1.911401  1.998382  2.053165  2.268226  2.149495  0.813609  1.083821
# 2  1.610768  1.530896  1.436820  1.949269  2.847876  0.758132  1.024094
# 3  0.846905  1.381909  0.740792  0.717000  3.161295  0.420712  0.290555
# 4  2.863910  2.766667  2.440248  3.395193  3.839845  1.853045  2.194574
#
#         FRA       DEU       GRC  ...       G-7     OECDE       COL       LVA  \
# 0  1.032283  1.509497  1.121259  ...  1.769906  2.482395  4.312141  2.930369
# 1  1.850815  1.732168  0.625621  ...  2.088463  3.020584  3.240234  2.534460
# 2  1.108255  1.445667  0.252993  ...  1.521069  2.612754  3.525493  2.811403
# 3  0.476499  0.506690 -1.247972  ...  0.874190  1.657686  2.524621  0.219061
# 4  1.642331  3.142970  1.223826  ...  3.493357  4.117882  3.495146  3.275814
#
#         SAU  EA19       ARG       LTU      G-20  EU27_2020
# ...

# %%
y_df.plot(figsize=(20,20))
# Out:
# <AxesSubplot:>
