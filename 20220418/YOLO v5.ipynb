# %%
from glob import glob

# %%
img_list = glob('./dataset/export/images/*.jpg')

# %%
len(img_list)
# Out:
# 2971

# %%
img_list
# Out:
# ['./dataset/export/images\\ (1).jpg',
#  './dataset/export/images\\ (10).jpg',
#  './dataset/export/images\\ (100).jpg',
#  './dataset/export/images\\ (1000).jpg',
#  './dataset/export/images\\ (1001).jpg',
#  './dataset/export/images\\ (1002).jpg',
#  './dataset/export/images\\ (1003).jpg',
#  './dataset/export/images\\ (1004).jpg',
#  './dataset/export/images\\ (1005).jpg',
#  './dataset/export/images\\ (1006).jpg',
#  './dataset/export/images\\ (1007).jpg',
#  './dataset/export/images\\ (1008).jpg',
#  './dataset/export/images\\ (1009).jpg',
#  './dataset/export/images\\ (101).jpg',
#  './dataset/export/images\\ (1010).jpg',
#  './dataset/export/images\\ (1011).jpg',
#  './dataset/export/images\\ (1012).jpg',
#  './dataset/export/images\\ (1013).jpg',
#  './dataset/export/images\\ (1014).jpg',
#  './dataset/export/images\\ (1015).jpg',
#  './dataset/export/images\\ (1016).jpg',
#  './dataset/export/images\\ (1017).jpg',
#  './dataset/export/images\\ (1018).jpg',
# ...

# %%
from sklearn.model_selection import train_test_split

train_img_list, val_img_list = train_test_split(img_list, test_size=0.2, random_state=2000)

print(len(train_img_list), len(val_img_list))
# Out:
# 2376 595

# %%
with open('./train.txt', 'w') as f:
    f.write('\n'.join(train_img_list) + '\n')
    
with open('./val.txt', 'w') as f:
    f.write('\n'.join(val_img_list) + '\n')

# %%
import yaml

with open('./data.yaml', 'r') as f:
    data = yaml.safe_load(f)
    
    print(data)
    
    data['train'] = "C:/Users/jesung/github/CodingLife/20220418/train.txt"
    data['val'] = "C:/Users/jesung/github/CodingLife/20220418/val.txt"
    
with open('./data.yaml', 'w') as f:
    yaml.dump(data, f)
        
print(data)
# Out:
# {'train': '../train/images', 'val': '../valid/images', 'nc': 1, 'names': ['pistol']}
# {'train': 'C:/Users/jesung/github/CodingLife/20220418/train.txt', 'val': 'C:/Users/jesung/github/CodingLife/20220418/val.txt', 'nc': 1, 'names': ['pistol']}

# %%
# !python ./yolov5/train.py --img 416 --batch 16 --epochs 50 --data ./data.yaml --cfg ./yolov5/models/yolov5s.yaml --weights ./yolov5/yolov5s.pt --name ./yolov5/gun_yolov5s_results
# Out:
# train: weights=./yolov5/yolov5s.pt, cfg=./yolov5/models/yolov5s.yaml, data=./data.yaml, hyp=yolov5\data\hyps\hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5\runs\train, name=./yolov5/gun_yolov5s_results, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5
# YOLOv5  v6.1-135-g7926afc torch 1.11.0+cpu CPU
#
# ...

# %%
# %load_ext tensorboard
# %tensorboard --logdir /runs/
# Out:
# Reusing TensorBoard on port 6006 (pid 12352), started 0:52:45 ago. (Use '!kill 12352' to kill it.)
#       <iframe id="tensorboard-frame-7e891461dfdedd88" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-7e891461dfdedd88");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
