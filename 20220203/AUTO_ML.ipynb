# %%
# data analysis and wrangling
import numpy as np
import pandas as pd
import json

# data standardization
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# data visualization
import seaborn as sns
import matplotlib.pyplot as plt

# deep learning
from keras import models
from keras import layers
from tensorflow.keras.utils import to_categorical

# %%
from pycaret.classification import *

# %%
from pycaret.utils import check_metric

# %%
train_df = pd.read_csv("preprocessed_train.csv", encoding='euc-kr')

# %%
train_df
# Out:
#       분석데이터  label  numstrings   avlength  printables   entropy  paths  urls  \
# 0         1      1         144  12.298611        1771  5.356616      0     0
# 1         2      1         804   9.580846        7703  6.063542      0     0
# 2         3      0        2205  12.736054       28083  6.107050      9     0
# 3         4      0        2602  10.288240       26770  5.373013      8     0
# 4         5      1        8980  23.252339      208806  5.775223      0    28
# ...     ...    ...         ...        ...         ...       ...    ...   ...
# 9995   9996      1        2018  13.938057       28127  5.940442      0    70
# 9996   9997      0        1105  16.437104       18163  5.766962      0    11
# 9997   9998      0           4  58.500000         234  3.811827      0     0
# 9998   9999      1        3312  24.939312       82599  5.834730      0    39
# 9999  10000      0         655   6.077863        3981  6.519481      0     0
#
# ...

# %%
exp1 = setup(train_df, target = 'label',
             ignore_features=['분석데이터'])
# Out:
# <style type="text/css">
# #T_3aa01_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_3aa01">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3aa01_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_3aa01_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3aa01_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3aa01_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_3aa01_row0_col1" class="data row0 col1" >6773</td>
#     </tr>
#     <tr>
#       <th id="T_3aa01_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3aa01_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_3aa01_row1_col1" class="data row1 col1" >label</td>
#     </tr>
#     <tr>
#       <th id="T_3aa01_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# ML 모델 성능 비교
top5 = compare_models(sort='Accuracy', n_select=5)
# Out:
# <style type="text/css">
# #T_e0fc0 th {
#   text-align: left;
# }
# ...

# %%
# 모델 튜닝, blending
tuned_top5 = [tune_model(i) for i in top5]
blender_top5 = blend_models(estimator_list=tuned_top5)
# Out:
# <style type="text/css">
# #T_5b533_row10_col0, #T_5b533_row10_col1, #T_5b533_row10_col2, #T_5b533_row10_col3, #T_5b533_row10_col4, #T_5b533_row10_col5, #T_5b533_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_5b533">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5b533_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_5b533_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_5b533_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_5b533_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_5b533_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_5b533_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_5b533_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b533_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
# 모델 최종 확정, 전체 데이터 학습
final_model = finalize_model(blender_top5)

# %%
# 테스트셋 predict
prediction = predict_model(final_model, data=train_df.iloc[-100:])

# %%
prediction
# Out:
#       분석데이터  label  numstrings    avlength  printables   entropy  paths  urls  \
# 9900   9901      1        6790  206.887923     1404769  5.023014      0     9
# 9901   9902      0        1392   13.699713       19070  5.707746      0     7
# 9902   9903      0         316   14.569620        4604  5.579481      0     1
# 9903   9904      0       20285    5.870348      119080  6.540629      0     0
# 9904   9905      0       29539    5.891533      174030  6.541591      1     0
# ...     ...    ...         ...         ...         ...       ...    ...   ...
# 9995   9996      1        2018   13.938057       28127  5.940442      0    70
# 9996   9997      0        1105   16.437104       18163  5.766962      0    11
# 9997   9998      0           4   58.500000         234  3.811827      0     0
# 9998   9999      1        3312   24.939312       82599  5.834730      0    39
# 9999  10000      0         655    6.077863        3981  6.519481      0     0
#
# ...

# %%
# metric 확인
check_metric(prediction['label'], prediction['Label'], metric = 'Accuracy')
# Out:
# 0.99
